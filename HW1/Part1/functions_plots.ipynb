# %%
import matplotlib.pyplot as plt
import numpy as np

# tanh plot
x = np.linspace(-10, 10, 200)
y = np.tanh(x)

# plot
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(-10, 10), xticks=np.arange(-10, 10),
       ylim=(-2, 2), yticks=np.arange(-2, 2))

plt.show()

# %%
#derivative of tanh plot
y = 1 - np.square(np.tanh(x))

# plot
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(-10, 10), xticks=np.arange(-10, 10),
       ylim=(-1, 2), yticks=np.arange(-1, 2))

plt.show()

# %%
#sigmoid plot
y = 1/(1+np.exp(-x))

# plot
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(-10, 10), xticks=np.arange(-10, 10),
       ylim=(-1, 2), yticks=np.arange(-1, 2))

plt.show()

# %%
#derivative of sigmoid function
sigmoid = 1/(1+np.exp(-x))
y = sigmoid * (1 - sigmoid)

# plot
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(-10, 10), xticks=np.arange(-10, 10),
       ylim=(-1, 2), yticks=np.arange(-1, 2))

plt.show()
# Out:
# -9.899497487437186

# %%
#ReLU

y = np.zeros(200)
for ind in range(0,200):
    if(x[ind]>0):
        y[ind] = x[ind]
    else:
        y[ind] = 0
        

# plot
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(-10, 10), xticks=np.arange(-10, 10),
       ylim=(-1, 10), yticks=np.arange(-1, 10))

plt.show()

# %%
#derivative of ReLU

y = np.zeros(200)
for ind in range(0,200):
    if(x[ind]>0):
        y[ind] = 1
    else:
        y[ind] = 0
        

# plot
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(-10, 10), xticks=np.arange(-10, 10),
       ylim=(-1, 2), yticks=np.arange(-1, 2))

plt.show()

# %%
 jupyter nbconvert functions_plot.ipynb --to pdf
# Out:
#   Cell In[2], line 1
#     jupyter nbconvert your_notebook.ipynb --to pdf
#             ^
# SyntaxError: invalid syntax
